# %% [markdown]
# <a href="https://colab.research.google.com/github/gio-gama/BasesComputacionais/blob/master/Tarefa_17_Giovanna_Gamaipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Giovanna Gama

# %%
import pandas as pd

# %%
futbr = pd.read_csv('https://raw.githubusercontent.com/gio-gama/BasesComputacionais/412adead4507cd1a54aec16a8e9d0c22cf9c2fb0/aula9/dados/tabelaBrasileirao2018.csv')
futbr
# Out:
#            Data  Turno         Mandante  Placar do Mandante  \
# 0    14/04/2018      1         Cruzeiro                   0
# 1    14/04/2018      1          Vitória                   2
# 2    14/04/2018      1           Santos                   2
# 3    15/04/2018      1  América Mineiro                   3
# 4    15/04/2018      1    Internacional                   2
# ..          ...    ...              ...                 ...
# 375   2/12/2018      2       Fluminense                   1
# 376   2/12/2018      2            Ceará                   0
# 377   2/12/2018      2        Palmeiras                   3
# 378   2/12/2018      2           Grêmio                   1
# 379   2/12/2018      2            Sport                   2
#
#      Placar do Visitante        Visitante  \
# 0                      1           Grêmio
# 1                      2         Flamengo
# 2                      0            Ceará
# 3                      0            Sport
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.figure()
plt.scatter(futbr['Público'], futbr['Renda (R$)'], 
            color='green')
plt.xlabel('Público (cm)')
plt.ylabel('Renda (R$) (cm)')
plt.show()
